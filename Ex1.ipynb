# %% [markdown]
# index.html

# %% [raw]
# <!DOCTYPE html>
# <html lang="">
#
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>p5.js example</title>
#   <style>
#     body {
#       padding: 0;
#       margin: 0;
#     }
#   </style>
#   <script src="../p5.js"></script>
#   <script src="../addons/p5.sound.js"></script>
#   <script src="sketch.js"></script>
# </head>
#
# <body>
#   <main>
#   </main>
# </body>
#
# </html>

# %% [markdown]
# sketch.js

# %% [raw]
# var mySound;
# var sliderVol;
# var amplitude;
# var fft;
# var reverb;
# var distortion;
# var compressor;
# let mic, recorder, soundFile;
# let state = 0;
# let lpfilter, filterFreq, filterRes;
# var spectrumin;
#
# function preload() {
#     soundFormats('wav', 'mp3');
#     prerecord = loadSound("../assets/prerecorded.wav");
#     mySound = loadSound("../assets/prerecorded.wav");
# }
#
# function setup() {
#     var canv = createCanvas(900, 900);
#     background(255,255,255);
#     gui();
#
#     specin = new p5.FFT();
#     specin.setInput(mySound);
#
#     lpfilter = new p5.LowPass();
#     fft = new p5.FFT();
#     reverb = new p5.Reverb();
#     distortion = new p5.Distortion();
#     compressor = new p5.Compressor();
#
#     mic = new p5.AudioIn();
#     // prompts user to enable their browser mic
#     mic.start();
#     recorder = new p5.SoundRecorder();
#     recorder.setInput(mic);
#     // soundFile will be used to save the recording
#     soundFile = new p5.SoundFile();
# }
#
# function draw() {
#     background(255);
#     guitext();
#     let vol = Math.pow(sliderVol.value(), 3);
#     mySound.setVolume(vol);
#
#     spectrumIn();
#     lowpass();
#     wavedist();
#     dynamicCompressor();
#     spectrumOut();
# }
#
# /////////////////////////////functions////////////////////////////////
#
# function pauseSound(){
#     mySound.pause();
# }
#
# function playSound(){
#     mySound.play();
# }
#
# function stopSound(){
#     mySound.stop();
# }
#
# function skipStart(){
#     mySound.jump();
# }
#
# function skipEnd(){
#     var dur = mySound.duration();
#     mySound.jump(dur - 5);
# }
#
# function loopSound(){
#     mySound.loop();
# }
#
# function record(){
#     // ensure audio is enabled
#     userStartAudio();
#
#     // make sure user enabled the mic
#     if (state === 0 && mic.enabled) {
#         // record to our p5.SoundFile
#         recorder.record(soundFile);
#
#         col = color(255,0,0);
#         recordButton.style("background-color",col);
#         state++;
#     }else if (state === 1) {
#         // background(0,255,0);
#         col = color(0,255,0);
#         recordButton.style("background-color",col);
#
#         // stop recorder and send result to soundFile
#         recorder.stop();
#         state++;
#     }else if (state === 2) {
#         col = color(125);
#         recordButton.style("background-color",col);
#         mySound = soundFile;
#         save(mySound, 'mySound.wav');
#         selectSound.option("mySound");
#         selectSound.selected("Select file");
#         state = 0;
#         selectSound.changed(selectionChange);
#     }
# }
#
# function reverseSound(){
#     mySound.reverseBuffer();
# }
#
# function spectrumIn(){
#     let spectrumin = specin.analyze();
#     push();
#     // Draw every value in the FFT spectrum analysis where
#     // x = lowest (10Hz) to highest (22050Hz) frequencies,
#     // h = energy (amplitude / volume) at that frequency
#     translate(520,320);
#     scale(0.33,0.20);
#     noStroke();
#     fill(60);
#     rect(0,0,width,height);
#     fill(255,0,0);
#     for (let i = 0; i<spectrumin.length; i++){
#         let x = map(i,0,spectrumin.length,0,width);
#         let h = -height + map(spectrumin[i],0,255,height,0);
#         rect(x, height, width/spectrumin.length, h);
#     }
#     pop();
# }
#
# function spectrumOut(){
#     let spectrum = fft.analyze();
#     push();
#     translate(520,540);
#     scale(0.33,0.20);
#     noStroke();
#     fill(60);
#     rect(0,0,width,height);
#     fill(255,0,0);
#     for (let i = 0; i<spectrum.length; i++){
#         let x = map(i,0,spectrum.length,0,width);
#         let h = -height + map(spectrum[i],0,255,height,0);
#         rect(x, height, width/spectrum.length, h);
#     }
#     pop();
# }
#
# function lowpass(){
#     let cf = sliderlpcf.value();
#     let res = sliderlpres.value();
#     filterFreq = map(cf, 0, 1, 10, 22050);
#     filterRes = map(res, 0, 1, 15, 5);
#     let drywetlp = sliderlpdw.value();
#     let op = sliderlpop.value();
#     lpfilter.set(filterFreq, filterRes);
#     lpfilter.drywet(drywetlp);
#     lpfilter.amp(op);
#     mySound.connect(lpfilter);
# }
#
# function reverbF(){
#     let decayr = sliderrevdr.value();
#     let revdur = sliderrevdur.value();
#     reverb.process(mySound,revdur,decayr);
#     let drywetrev = sliderrevdw.value();
#     reverb.drywet(drywetrev);
#     let op = sliderrevop.value();
#     reverb.amp(op);
# }
#
# function wavedist(){
#     let distamt = sliderwdda.value();
#     let oversample = sliderwdos.value();
#     if (oversample === 0){
#         oversample = "none";
#     }else if (oversample === 1){
#         oversample = "2x";
#     }else if (oversample === 2){
#         oversample = "4x";
#     }
#     distortion.process(mySound,distamt,oversample);
#     let op = sliderwdop.value();
#     distortion.amp(op);
#     let drywetwd = sliderwddw.value();
#     distortion.drywet(drywetwd);
# }
#
# function dynamicCompressor(){
#     let attackval = sliderdcatt.value();
#     compressor.attack(attackval);
#     let kneeval = sliderdcknee.value();
#     compressor.knee(kneeval);
#     let ratioval = sliderdcrat.value();
#     compressor.ratio(ratioval);
#     let thresholdval = sliderdcth.value();
#     compressor.threshold(thresholdval);
#     let releaseval = sliderdcrel.value();
#     compressor.release(releaseval);
#     compressor.process(mySound, attackval,kneeval,ratioval,thresholdval,releaseval);
#     let drywetdc = sliderdcdw.value();
#     compressor.drywet(drywetdc);
#     let op = sliderdcop.value();
#     compressor.amp(op);
# }
#
# //further development
# function selectionChange(){
#     mySound.stop();
#     let sel = selectSound.value();
#     if (sel === "mySound"){
#         mySound = soundFile;
#         mySound.play();
#         specin.setInput(mySound);
#         spectrumIn();
#         spectrumOut();
#     }else if (sel === "Pre-recorded"){
#         mySound = prerecord;
#         mySound.play();
#         specin.setInput(mySound);
#         spectrumIn();
#         spectrumOut();
#     }else if (sel === "Select file"){
#         mySound.stop();
#     }
# }
#
# function gui(){
#     ///////////////////////////////buttons///////////////////////////////
#     pauseButton = createButton("pause");
#     pauseButton.position(20,20);
#     pauseButton.mousePressed(pauseSound);
#
#     playButton = createButton("play");
#     playButton.position(80,20);
#     playButton.mousePressed(playSound);
#
#     stopButton = createButton("stop");
#     stopButton.position(130,20);
#     stopButton.mousePressed(stopSound);
#
#     skipStartButton = createButton("skip to start");
#     skipStartButton.position(180,20);
#     skipStartButton.mousePressed(skipStart);
#
#     skipEndButton = createButton("skip to end");
#     skipEndButton.position(270,20);
#     skipEndButton.mousePressed(skipEnd);
#
#     loopButton = createButton("loop");
#     loopButton.position(360,20);
#     loopButton.mousePressed(loopSound);
#
#     recordButton = createButton("record");
#     recordButton.position(410,20);
#     recordButton.mousePressed(record);
#
#     reverseButton = createButton("reverse");
#     reverseButton.position(40,500);
#     reverseButton.mousePressed(reverseSound);
#
#     //further development
#     selectSound = createSelect();
#     selectSound.position(480,20);
#     selectSound.option("Pre-recorded");
#     selectSound.option("Select file");
#     selectSound.disable("Select file");
#     selectSound.selected("Pre-recorded");
#     mySound = prerecord;
#     selectSound.changed(selectionChange);
#
#     ///////////////////////////sliders///////////////////////////
#
#     sliderVol = createSlider(0,1,0.5,0.1);
#     sliderVol.position(490,150);
#     sliderVol.style("transform","rotate(270deg)");
#
#     //lowpass cutoff freq
#     sliderlpcf = createSlider(0,1,0.5,0.01);
#     sliderlpcf.position(20,130);
#
#     //lowpass resonance
#     sliderlpres = createSlider(0,1,0.5,0.01);
#     sliderlpres.position(150,130);
#
#     //lowpass dry/wet
#     sliderlpdw = createSlider(0,1,0.5,0.1);
#     sliderlpdw.position(20,250);
#     sliderlpdw.style("transform","rotate(270deg)");
#
#     //lowpass output
#     sliderlpop = createSlider(0,1,0.5,0.1);
#     sliderlpop.position(150,250);
#     sliderlpop.style("transform","rotate(270deg)");
#
#     //dynamic compressor attack
#     sliderdcatt = createSlider(0,1,0,0.1);
#     sliderdcatt.position(320,100);
#
#     //dynamic compressor knee
#     sliderdcknee = createSlider(0,40,30,1);
#     sliderdcknee.position(320,140);
#
#     //dynamic compressor release
#     sliderdcrel = createSlider(0,1,0.2,0.1);
#     sliderdcrel.position(320,180);
#
#     //dynamic compressor ratio
#     sliderdcrat = createSlider(1,20,12,1);
#     sliderdcrat.position(260,220);
#
#     //dynamic compressor threshold
#     sliderdcth = createSlider(-100,0,-24,1);
#     sliderdcth.position(400,220);
#
#     //dynamic compressor dry/wet
#     sliderdcdw = createSlider(0,100,50,1);
#     sliderdcdw.position(280,320);
#     sliderdcdw.style("transform","rotate(270deg)");
#
#     //dynamic compressor output
#     sliderdcop = createSlider(0,1,1,0.1);
#     sliderdcop.position(370,320);
#     sliderdcop.style("transform","rotate(270deg)");
#
#     //reverb duration
#     sliderrevdur = createSlider(0,10,0,1);
#     sliderrevdur.position(10,450);
#     sliderrevdur.changed(reverbF);
#
#     //reverb decay rate
#     sliderrevdr = createSlider(0,100,0,1);
#     sliderrevdr.position(140,450);
#     sliderrevdr.changed(reverbF);
#
#     //reverb dry/wet
#     sliderrevdw = createSlider(0,1,0,1);
#     sliderrevdw.position(20,620);
#     sliderrevdw.style("transform","rotate(270deg)");
#
#     //reverb output
#     sliderrevop = createSlider(0,1,1,0.1);
#     sliderrevop.position(120,620);
#     sliderrevop.style("transform","rotate(270deg)");
#
#     //waveshaper distortion amount
#     sliderwdda = createSlider(0,1,0.5,0.1);
#     sliderwdda.position(250,480);
#
#     //waveshaper distortion oversample
#     sliderwdos = createSlider(0,2,0,1);
#     sliderwdos.position(380,480);
#
#     //waveshaper distortion dry/wet
#     sliderwddw = createSlider(0,100,50,1);
#     sliderwddw.position(250,600);
#     sliderwddw.style("transform","rotate(270deg)");
#
#     //waveshaper distortion output
#     sliderwdop = createSlider(0,1,1,0.1);
#     sliderwdop.position(370,600);
#     sliderwdop.style("transform","rotate(270deg)");
# }
#
# function guitext(){
#     push();
#     textSize(18);
#     text("low-pass filter",100,80);
#     text("master volume",500,80);
#     text("dynamic compressor",300,80);
#     text("reverb",120,380);
#     text("waveshaper distortion",300,440);
#     text("spectrum in",520,300);
#     text("spectrum out",520,520);
#     fill(125);
#     pop();
#
#     //low-pass filter
#     text("cutoff frequency",60,110);
#     text("resonance",180, 110);
#     text("dry/wet",60,180);
#     text("output level",180,180);
#
#     //dynamic compressor
#     text("attack",380,100);
#     text("knee",380,140);
#     text("release",380,180);
#     text("ratio",320,220);
#     text("threshold",450,220);
#     text("dry/wet",320,250);
#     text("output level",400,250);
#
#     //reverb
#     text("reverb duration",40,420);
#     text("decay rate",150,420);
#     text("dry/wet",60,550);
#     text("output level",150,550);
#
#     //waveshaper distortion
#     text("distortion amount",280,460);
#     text("oversample",400,460);
#     text("dry/wet",300,530);
#     text("output level",400,530);
# }

# %% [markdown]
# file directory

# %% [markdown]
# ![image.png](attachment:image.png)
